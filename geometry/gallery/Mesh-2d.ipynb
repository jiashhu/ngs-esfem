# %%
from geometry import *
from ngsolve.webgui import Draw

# %%
mymesh = quadfoil_in_square(0.3,2)

Draw(mymesh)
# Out:
# WebGuiWidget(layout=Layout(height='50vh', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.23…
# BaseWebGuiScene

# %%
mymesh = quadfoil(0.3)
Draw(mymesh)
# Out:
# WebGuiWidget(layout=Layout(height='50vh', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.23…
# BaseWebGuiScene

# %%
mymesh = quadfoil_in_circ(0.3,1)

Draw(mymesh)
# Out:
# WebGuiWidget(layout=Layout(height='50vh', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.23…
# BaseWebGuiScene
